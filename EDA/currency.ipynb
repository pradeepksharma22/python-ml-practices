# %%
# All imports
import numpy as np
import pandas as pd
from numpy import cov
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
warnings.filterwarnings("ignore")

# %%
currency_df = pd.read_csv('currencies.csv')
print(currency_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 52 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Currency                    11 non-null     object
#  1   Chinese Yuan                11 non-null     float64
#  2   Euro                        11 non-null     float64
#  3   Japanese Yen                10 non-null     float64
#  4   U.K. Pound Sterling         11 non-null     float64
#  5   U.S. Dollar                 11 non-null     float64
#  6   Algerian Dinar              9 non-null      float64
#  7   Australian Dollar           11 non-null     float64
#  8   Bahrain Dinar               11 non-null     float64
#  9   Botswana Pula               9 non-null      float64
#  10  Brazilian Real              11 non-null     float64
#  11  Brunei Dollar               10 non-null     float64
#  12  Canadian Dollar             10 non-null     float64
# ...

# %%
#Once you create the correlation matrix, you need to compare the correlation between 
# each pair with the rest and choose the best pair. 
#For example, you would compare the correlation between INR and US Dollar with INR and Euro.

# %%
currency_df = currency_df.fillna(0)

# %%
#columns = [ "Euro", 'U.S. Dollar', "Australian Dollar", "Japanese Yen"], value="Currency")

r = np.corrcoef(currency_df["Euro"], currency_df["Indian Rupee"])
r
# Out:
# array([[ 1.        , -0.04964905],
#        [-0.04964905,  1.        ]])

# %%
currency_df.head()
# Out:
#         Currency  Chinese Yuan     Euro  Japanese Yen  U.K. Pound Sterling  \
# 0  July 01, 2016       9.29446  1.25367       143.645              1.05054
# 1  July 05, 2016       9.31515  1.25322       142.715              1.06143
# 2  July 06, 2016       9.31697  1.25834       140.540              1.07300
# 3  July 07, 2016       9.31315  1.25737       140.640              1.06911
# 4  July 08, 2016       9.31350  1.25797       140.510              1.07261
#
#    U.S. Dollar  Algerian Dinar  Australian Dollar  Bahrain Dinar  \
# 0      1.39596           0.000            1.87126       0.524882
# 1      1.39684         154.063            1.85825       0.525213
# 2      1.39286         154.094            1.87313       0.523717
# 3      1.39316         153.957            1.85236       0.523829
# 4      1.39257         154.062            1.85974       0.523607
#
#    Botswana Pula  ...  South African Rand  Sri Lanka Rupee  Swedish Krona  \
# ...

# %%
r = np.corrcoef(currency_df["U.S. Dollar"], currency_df["Indian Rupee"])
r
# Out:
# array([[ 1.        , -0.14999411],
#        [-0.14999411,  1.        ]])

# %%
#columns = [ "Euro", 'U.S. Dollar', "Australian Dollar", "Japanese Yen"], value="Currency")

r = np.corrcoef(currency_df["Australian Dollar"], currency_df["Indian Rupee"])
r
# Out:
# array([[ 1.        , -0.12826156],
#        [-0.12826156,  1.        ]])

# %%
r = np.corrcoef(currency_df["Japanese Yen"], currency_df["Indian Rupee"])
r
# Out:
# array([[ 1.       , -0.1567576],
#        [-0.1567576,  1.       ]])

# %%
corr = currency_df.corr()
corr
# Out:
#                             Chinese Yuan      Euro  Japanese Yen  \
# Chinese Yuan                    1.000000  0.151596      0.206963
# Euro                            0.151596  1.000000     -0.170324
# Japanese Yen                    0.206963 -0.170324      1.000000
# U.K. Pound Sterling             0.108695  0.531150      0.221966
# U.S. Dollar                     0.291582 -0.210587      0.534522
# Algerian Dinar                  0.220580  0.289123     -0.177194
# Australian Dollar               0.077983  0.331588      0.308892
# Bahrain Dinar                   0.291926 -0.209926      0.533954
# Botswana Pula                   0.577388  0.013381      0.664694
# Brazilian Real                  0.320508  0.383645      0.171104
# Brunei Dollar                  -0.333793 -0.313389     -0.080181
# Canadian Dollar                 0.562577  0.151434     -0.102244
# Chilean Peso                    0.028821  0.242743      0.629436
# ...

# %%
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# ...

# %%
def plot_corr(df,size=10):
    """Function plots a graphical correlation matrix for each pair of columns in the dataframe.

    Input:
        df: pandas DataFrame
        size: vertical and horizontal size of the plot
    """

    corr = df.corr()
    fig, ax = plt.subplots(figsize=(size, size))
    ax.matshow(corr)
    plt.xticks(range(len(corr.columns)), corr.columns)
    plt.yticks(range(len(corr.columns)), corr.columns)

# %%
currency_df1 = currency_df[["Euro", 'U.S. Dollar', "Australian Dollar", "Japanese Yen", "Indian Rupee", "U.K. Pound Sterling", "Chinese Yuan"]]
plot_corr(currency_df1)

# %%
f, ax = plt.subplots(figsize=(10, 8))
corr = currency_df1.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True,annot = True, ax=ax)
# Out:
# <AxesSubplot:>
