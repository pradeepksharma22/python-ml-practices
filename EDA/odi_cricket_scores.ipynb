# %%
# All imports
import numpy as np
import pandas as pd

pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv('tendulkar_ODI.csv')
df.shape
df.head()
# Out:
#    Unnamed: 0 Runs Mins  BF 4s 6s      SR Pos Dismissal Inns     Opposition  \
# 0           1    0    -   2  0  0       0   5    caught    2     v Pakistan
# 1           2    0    2   2  0  0       0   5    caught    2  v New Zealand
# 2           3   36   51  39  5  0    92.3   6    caught    1  v New Zealand
# 3           4   19   38  35  1  1   54.28   4    bowled    2      v England
# 4           5   31   31  26  3  0  119.23   6    bowled    2      v England
#
#        Ground Start Date
# 0  Gujranwala  18-Dec-89
# 1     Dunedin   1-Mar-90
# 2  Wellington   6-Mar-90
# 3       Leeds  18-Jul-90
# 4  Nottingham  20-Jul-90

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Runs          0
# Mins          0
# BF            0
# 4s            0
# 6s            0
# SR            0
# Pos           0
# Dismissal     0
# Inns          0
# Opposition    0
# Ground        0
# Start Date    0
# dtype: int64

# %%
df['Runs'].value_counts()
# Out:
# 1      16
# 2      14
# 0      12
# 4       9
# 21      8
#        ..
# 139     1
# 70*     1
# 101     1
# 87*     1
# 85      1
# Name: Runs, Length: 118, dtype: int64

# %%
def clean_Runs(val):
   return val.replace("*","0").replace("TDNB","0").replace("DNB","0")

df.Runs = df.Runs.apply(clean_Runs)

# %%
#df["Runs"] = df["Runs"].apply(lambda x:'0'.join(x.split('*')))

# %%
df['Runs'].value_counts()
# Out:
# 1      16
# 0      15
# 2      14
# 4       9
# 21      8
#        ..
# 139     1
# 700     1
# 101     1
# 870     1
# 85      1
# Name: Runs, Length: 115, dtype: int64

# %%
#df["Runs"] = df["Runs"].apply(lambda x:'0'.join(x.split('DNB')))

# %%
#df["Runs"] = df["Runs"].apply(lambda x:'0'.join(x.split('TDNB')))

# %%
#df["Runs"] = df["Runs"].apply(lambda x:'0'.join(x.split('TO')))

# %%
#df.Runs == "TO"

# %%
df.Runs = df.Runs.astype("int32")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295 entries, 0 to 294
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  295 non-null    int64
#  1   Runs        295 non-null    int32
#  2   Mins        295 non-null    object
#  3   BF          295 non-null    object
#  4   4s          295 non-null    object
#  5   6s          295 non-null    object
#  6   SR          295 non-null    object
#  7   Pos         295 non-null    object
#  8   Dismissal   295 non-null    object
#  9   Inns        295 non-null    object
#  10  Opposition  295 non-null    object
#  11  Ground      295 non-null    object
#  12  Start Date  295 non-null    object
# dtypes: int32(1), int64(1), object(11)
# memory usage: 28.9+ KB

# %%
df.head()
# Out:
#    Unnamed: 0  Runs Mins  BF 4s 6s      SR Pos Dismissal Inns     Opposition  \
# 0           1     0    -   2  0  0       0   5    caught    2     v Pakistan
# 1           2     0    2   2  0  0       0   5    caught    2  v New Zealand
# 2           3    36   51  39  5  0    92.3   6    caught    1  v New Zealand
# 3           4    19   38  35  1  1   54.28   4    bowled    2      v England
# 4           5    31   31  26  3  0  119.23   6    bowled    2      v England
#
#        Ground Start Date
# 0  Gujranwala  18-Dec-89
# 1     Dunedin   1-Mar-90
# 2  Wellington   6-Mar-90
# 3       Leeds  18-Jul-90
# 4  Nottingham  20-Jul-90

# %%
df[(df["Runs"] == 0) & (df["Runs"] <= 10)]
# Out:
#      Unnamed: 0  Runs Mins  BF 4s 6s SR Pos Dismissal Inns      Opposition  \
# 0             1     0    -   2  0  0  0   5    caught    2      v Pakistan
# 1             2     0    2   2  0  0  0   5    caught    2   v New Zealand
# 8             9     0    -   -  -  -  -   -         -    2    v Bangladesh
# 38           39     0    -   -  -  -  -   -         -    2      v Zimbabwe
# 56           57     0    6   2  0  0  0   2    caught    2     v Sri Lanka
# 57           58     0    3   4  0  0  0   2    caught    2   v West Indies
# 58           59     0    7   4  0  0  0   2    caught    2   v West Indies
# 90           91     0   12   4  0  0  0   2    bowled    2  v South Africa
# 127         128     0   10   5  0  0  0   2    caught    1   v New Zealand
# 137         138     0    2   3  0  0  0   4    caught    2   v New Zealand
# 176         177     0    9  10  0  0  0   4       lbw    2   v New Zealand
# ...

# %%
df[(df["Runs"] > 10) & (df["Runs"] <= 20)]
# Out:
#      Unnamed: 0  Runs Mins  BF 4s 6s      SR Pos Dismissal Inns  \
# 3             4    19   38  35  1  1   54.28   4    bowled    2
# 20           21    11   19  19  1  0   57.89   4    caught    2
# 23           24    15    -  27  1  0   55.55   4    bowled    1
# 40           41    15    -  30  0  0      50   5   run out    2
# 45           46    15    -  31  3  0   48.38   5    caught    1
# 50           51    15   22  19  1  0   78.94   5    caught    2
# 67           68    13   30  15  3  0   86.66   2    caught    1
# 83           84    11   20   8  2  0   137.5   2    caught    2
# 92           93    14   34  24  2  0   58.33   3    caught    1
# 94           95    13   18  15  0  1   86.66   2    caught    1
# 117         118    15   45  24  2  0    62.5   2    caught    1
# 119         120    18   33  25  2  0      72   2    caught    2
# 122         123    17   28  16  4  0  106.25   2    caught    2
# 138         139    12   25  11  2  0  109.09   4   run out    2
# ...

# %%
df[(df["Runs"] > 20) & (df["Runs"] <= 30)]
# Out:
#      Unnamed: 0  Runs Mins  BF 4s 6s      SR Pos Dismissal Inns  \
# 7             8    30    -  29  1  2  103.44   5    caught    1
# 16           17    21   38  35  3  0      60   4    caught    1
# 25           26    22    -  24  2  0   91.66   5    caught    2
# 26           27    21    -  44  1  0   47.72   5    caught    1
# 28           29    23    -  39  0  0   58.97   5    caught    2
# 29           30    21    -  38  3  0   55.26   3    caught    2
# 33           34    24   42  32  1  0      75   4    bowled    1
# 39           40    21    -  39  1  0   53.84   5    caught    1
# 41           42    25    -  39  1  0    64.1   5    caught    1
# 68           69    30   30  20  5  0     150   2    caught    1
# 86           87    28   55  38  5  0   73.68   1       lbw    1
# 102         103    21   49  28  3  0      75   1    bowled    1
# 104         105    27   55  28  3  0   96.42   1    caught    2
# 108         109    21   24  18  2  1  116.66   1    caught    2
# ...

# %%
df[(df["Runs"] > 30) & (df["Runs"] <= 40)]
# Out:
#      Unnamed: 0  Runs Mins  BF 4s 6s      SR Pos Dismissal Inns  \
# 2             3    36   51  39  5  0    92.3   6    caught    1
# 4             5    31   31  26  3  0  119.23   6    bowled    2
# 5             6    36    -  22  3  2  163.63   5    bowled    1
# 14           15    36   79  65  3  0   55.38   4    caught    1
# 17           18    31   64  44  1  0   70.45   5   run out    1
# 22           23    39   92  56  7  0   69.64   4    caught    1
# 27           28    32    -  52  1  0   61.53   5    bowled    1
# 35           36    34   42  30  2  1  113.33   5    caught    2
# 53           54    40   34  26  8  0  153.84   2    bowled    1
# 61           62    34   53  47  7  0   72.34   2    bowled    2
# 69           70    39   79  51  4  0   76.47   2    caught    2
# 78           79    31  103  59  3  0   52.54   2    bowled    1
# 106         107    39   41  32  3  2  121.87   1    caught    2
# 118         119    33   48  29  6  0  113.79   2    caught    2
# ...

# %%
df['Runs'].value_counts()
# Out:
# 1      16
# 0      15
# 2      14
# 4       9
# 21      8
#        ..
# 139     1
# 700     1
# 101     1
# 870     1
# 85      1
# Name: Runs, Length: 115, dtype: int64

# %%
df['4s'].value_counts()
# Out:
# 0     69
# 1     37
# 2     29
# 3     25
# 4     17
# 5     16
# 9     15
# 6     14
# 8     13
# 7     13
# 10    11
# 13     8
# 12     5
# 15     4
# 11     4
# 16     4
# -      3
# 14     3
# 19     2
# 20     1
# 17     1
# 25     1
# Name: 4s, dtype: int64

# %%
odi_batting_df = pd.read_csv('odi-batting.csv')
odi_batting_df.describe()
# Out:
#                Runs         Balls
# count  50284.000000  50284.000000
# mean      24.725141     34.019052
# std       25.783347     30.773306
# min        1.000000      1.000000
# 25%        6.000000     11.000000
# 50%       16.000000     24.000000
# 75%       35.000000     48.000000
# max      200.000000    210.000000

# %%
odi_batting_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50284 entries, 0 to 50283
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    50284 non-null  object
#  1   Player     50284 non-null  object
#  2   Runs       50284 non-null  int64
#  3   MatchDate  50284 non-null  object
#  4   Weekday    50284 non-null  object
#  5   Ground     50284 non-null  object
#  6   Versus     50284 non-null  object
#  7   Balls      50284 non-null  int64
# dtypes: int64(2), object(6)
# memory usage: 3.1+ MB

# %%
odi_batting_df_cen = odi_batting_df[["Player", "Runs", "Balls", "MatchDate", "Country"]]

# %%
odi_batting_df_cen.head()
# Out:
#              Player  Runs  Balls   MatchDate      Country  centuries  \
# 0  Mohammad Shahzad   118    121  16-02-2010  Afghanistan       True
# 1  Mohammad Shahzad   110    111  01-09-2009  Afghanistan       True
# 2  Mohammad Shahzad   100     72  16-08-2010  Afghanistan       True
# 3  Mohammad Shahzad    82    108  10-07-2010  Afghanistan      False
# 4  Mohammad Shahzad    57     57  01-07-2010  Afghanistan      False
#
#    strike_rate  year
# 0     0.975207  2010
# 1     0.990991  2009
# 2     1.388889  2010
# 3     0.759259  2010
# 4     1.000000  2010

# %%
odi_batting_df_cen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50284 entries, 0 to 50283
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player       50284 non-null  object
#  1   Runs         50284 non-null  int64
#  2   Balls        50284 non-null  int64
#  3   MatchDate    50284 non-null  object
#  4   centuries    50284 non-null  bool
#  5   strike_rate  50284 non-null  float64
#  6   year         50284 non-null  object
# dtypes: bool(1), float64(1), int64(2), object(3)
# memory usage: 2.3+ MB

# %%
odi_batting_df_cen["centuries"] = odi_batting_df_cen["Runs"]>=100
# Out:
# /var/folders/43/859d2zb56t3_rbldq_3tyncmhd0n5m/T/ipykernel_51840/129737742.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   odi_batting_df_cen["centuries"] = odi_batting_df_cen["Runs"]>=100

# %%
odi_batting_df_cen.value_counts()
# Out:
# Player              Runs  Balls  MatchDate   Country   centuries
# Aamer Hanif         17    24     02-11-1993  Pakistan  False        1
# Owais A Shah        44    40     31-08-2008  England   False        1
#                     45    64     04-07-2007  England   False        1
#                     49    25     15-06-2008  England   False        1
#                     51    66     07-07-2007  England   False        1
#                                                                    ..
# Hamilton Masakadza  44    42     15-10-2009  Zimbabwe  False        1
#                     46    43     28-05-2010  Zimbabwe  False        1
#                     48    55     26-08-2007  Zimbabwe  False        1
#                     54    53     20-09-2006  Zimbabwe  False        1
# Zulquarnain         11    10     30-03-1986  Pakistan  False        1
# Length: 50284, dtype: int64

# %%
#Create a new column which contains 1 if the player scores more than 100 runs and 0 otherwise. 
#Once you create the new column, sum up all the 1s grouped by the player name.

# %%
odi_batting_df_cen[(odi_batting_df_cen["centuries"] == True) & (odi_batting_df_cen["Player"] == "Sachin R Tendulkar")].groupby(odi_batting_df_cen["centuries"]).sum()
# Out:
#            Runs  Balls  centuries  strike_rate
# centuries
# True       6008   5981         48    48.623615

# %%
odi_batting_df_cen[(odi_batting_df_cen["centuries"] == True) & (odi_batting_df_cen["Player"] == "Ricky T Ponting")].groupby(odi_batting_df_cen["centuries"]).sum()
# Out:
#            Runs  Balls  centuries  strike_rate
# centuries
# True       3524   3526         30    30.171934

# %%
odi_batting_df_cen["strike_rate"] = odi_batting_df_cen["Runs"]/odi_batting_df_cen["Balls"]
# Out:
# /var/folders/43/859d2zb56t3_rbldq_3tyncmhd0n5m/T/ipykernel_51840/3842108601.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   odi_batting_df_cen["strike_rate"] = odi_batting_df_cen["Runs"]/odi_batting_df_cen["Balls"]

# %%
odi_batting_df_cen[(odi_batting_df_cen["centuries"] == True) & (odi_batting_df_cen["Player"] == "Shahid Afridi")].value_counts()
# Out:
# Player         Runs  Balls  MatchDate   Country   centuries  strike_rate
# Shahid Afridi  102   40     04-10-1996  Pakistan  True       2.550000       1
#                      46     15-04-2005  Pakistan  True       2.217391       1
#                108   92     15-04-2002  Pakistan  True       1.173913       1
#                109   76     15-06-2010  Pakistan  True       1.434211       1
#                      94     19-09-1998  Pakistan  True       1.159574       1
#                124   60     21-06-2010  Pakistan  True       2.066667       1
# dtype: int64

# %%
#You need to calculate the strike rate from the “run” and “balls” columns 
#and then subset the data to include all the centuries scored.

# %%
odi_batting_df_cen["year"] = odi_batting_df_cen["MatchDate"].apply(lambda x : x[6:])

# %%
odi_batting_df_cen.head()
# Out:
#              Player  Runs  Balls   MatchDate      Country  centuries  \
# 0  Mohammad Shahzad   118    121  16-02-2010  Afghanistan       True
# 1  Mohammad Shahzad   110    111  01-09-2009  Afghanistan       True
# 2  Mohammad Shahzad   100     72  16-08-2010  Afghanistan       True
# 3  Mohammad Shahzad    82    108  10-07-2010  Afghanistan      False
# 4  Mohammad Shahzad    57     57  01-07-2010  Afghanistan      False
#
#    strike_rate  year
# 0     0.975207  2010
# 1     0.990991  2009
# 2     1.388889  2010
# 3     0.759259  2010
# 4     1.000000  2010

# %%
odi_batting_df_cen[(odi_batting_df_cen["Country"] == "India") & (odi_batting_df_cen["Runs"] >= 100)].groupby("year").Runs.count()
# Out:
# year
# 1983     1
# 1984     3
# 1986     2
# 1987     4
# 1988     5
# 1989     2
# 1990     3
# 1991     2
# 1992     1
# 1993     2
# 1994     7
# 1995     1
# 1996     8
# 1997     7
# 1998    18
# 1999    15
# 2000    10
# 2001     9
# 2002     9
# 2003    10
# 2004     7
# 2005    11
# 2006     5
# 2007     5
# 2008    10
# 2009    13
# 2010    12
# 2011     8
# Name: Runs, dtype: int64

# %%
#Create a new metric from the date column — “year”. 
#Then, subset your data with country = ‘India’ and aggregate the number of centuries by year. 
#In Excel, you can use the YEAR() function to extract the year from the date 
# and then use a pivot table to cross tabulate the year and number of centuries for Indian players.
